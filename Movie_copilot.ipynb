# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Sohan\\Downloads\\Movies_dataset_csv'

# %%
import pandas as pd

df_movies = pd.read_csv('C:/Users/Sohan/Downloads/Movies_dataset_csv/movies.csv')
df_titles = pd.read_csv('C:/Users/Sohan/Downloads/Movies_dataset_csv/netflix_titles.csv')
df_users = pd.read_csv('C:/Users/Sohan/Downloads/Movies_dataset_csv/users.csv')
df_history = pd.read_csv('C:/Users/Sohan/Downloads/Movies_dataset_csv/watch_history.csv')

# %%
# Create 'title_clean' so we can link Movies to Netflix Titles
df_titles['title_clean'] = df_titles['title'].str.lower().str.strip()
df_movies['title_clean'] = df_movies['title'].str.lower().str.strip()

# %%
##Clean Duration in netflix_titles (e.g. "90 min" -> 90)
def clean_duration(val):
    if pd.isna(val): return 0
    val = str(val).lower()
    if 'min' in val:
        return int("".join(filter(str.isdigit, val)))
    elif 'season' in val:
        # For simplicity in this project, we can treat seasons differently or just track the number
        return int("".join(filter(str.isdigit, val)))
    return 0

df_titles['duration_clean'] = df_titles['duration'].apply(clean_duration)

# %%
# Updated line
df_users = df_users.drop(columns=['email', 'first_name', 'last_name'], errors='ignore')

# %%
# 3. CREATE THE MASTER DATAFRAME
print("Merging data...")
# Merge History + Movies
df_master = pd.merge(df_history, df_movies, on='movie_id', how='left', suffixes=('', '_movies'))

# Merge + Users
df_master = pd.merge(df_master, df_users, on='user_id', how='left', suffixes=('', '_users'))

# Merge + Creative (Director/Cast from Netflix Titles)
df_creative = df_titles[['title_clean', 'director', 'cast', 'listed_in', 'duration_clean']]
df_master = pd.merge(df_master, df_creative, on='title_clean', how='left')

# Calculate ROI (Revenue - Budget)
df_master['roi'] = df_master['box_office_revenue'] - df_master['production_budget']
df_master['watch_date'] = pd.to_datetime(df_master['watch_date'])

# 4. DATA HEALTH CHECK & WARNINGS
print("-" * 30)
print(f"Master View Created: {df_master.shape[0]} rows.")
print("-" * 30)
# Out:
# Merging data...
# ------------------------------
# Master View Created: 112546 rows.
# ------------------------------

# %%
# CHECK 1: Financial Data Link
missing_financials = df_master['production_budget'].isnull().sum()
print(f"Rows missing Financial Data: {missing_financials} ({(missing_financials/len(df_master))*100:.1f}%)")
# Out:
# Rows missing Financial Data: 73022 (64.9%)

# %%
missing_creative = df_master['director'].isnull().sum()
print(f"Rows missing Director/Cast Data: {missing_creative} ({(missing_creative/len(df_master))*100:.1f}%)")

if (missing_creative/len(df_master)) > 0.8:
    print("\n⚠️ WARNING: High mismatch between 'movies.csv' and 'netflix_titles.csv'.")
    print("Question 9 (Directors) may not have enough data to answer accurately.")
    print("This happens because the movie titles in your financial file don't match the Netflix library file.")
# Out:
# Rows missing Director/Cast Data: 112230 (99.7%)
#
# ⚠️ WARNING: High mismatch between 'movies.csv' and 'netflix_titles.csv'.
# Question 9 (Directors) may not have enough data to answer accurately.
# This happens because the movie titles in your financial file don't match the Netflix library file.

# %%
## HANDLING THE FINANCIAL GAP
##creating a specific subset for ROI analysis

df_financials = df_master.dropna(subset=['production_budget', 'box_office_revenue']).copy()
print(f"Financial Analysis Universe: {len(df_financials)} verified records.")
# Out:
# Financial Analysis Universe: 29094 verified records.

# %%
# DROPPING THE FAILED CREATIVE LINK
df_master = df_master.drop(columns=['director', 'cast', 'listed_in'], errors='ignore')
print("Dropped incompatible creative columns (Director/Cast).")
# Out:
# Dropped incompatible creative columns (Director/Cast).

# %%
df_movies['roi'] = df_movies['box_office_revenue'] - df_movies['production_budget']

# %%
df_master['is_high_engagement'] = df_master['progress_percentage'] > 80   ## engagement percentage of user's content choice

# %%
print(f"Master Dataframe Shape: {df_master.shape}")  ## printing the final dataset for analysis
df_master.head()
# Out:
# Master Dataframe Shape: (112546, 45)
#        session_id     user_id    movie_id watch_date device_type  \
# 0  session_000001  user_07271  movie_0511 2025-11-13      Tablet
# 1  session_000002  user_00861  movie_0588 2025-02-26      Laptop
# 2  session_000003  user_05391  movie_0694 2024-12-15     Desktop
# 3  session_000004  user_05192  movie_0234 2024-09-30     Desktop
# 4  session_000005  user_05735  movie_0390 2024-08-04      Tablet
#
#    watch_duration_minutes  progress_percentage     action quality  \
# 0                    63.9                 34.6  completed      HD
# 1                   120.1                 44.2    started      HD
# 2                   572.1                 84.7    started      HD
# 3                   395.3                 89.9  completed      SD
# 4                    14.6                  6.2  completed      HD
#
#   location_country  ...  subscription_plan  subscription_start_date is_active  \
# 0              USA  ...              Basic               18-09-2024      True
# 1              USA  ...           Standard               18-06-2025      True
# 2           Canada  ...              Basic               16-01-2023      True
# 3              USA  ...           Premium+               27-02-2024      True
# 4              USA  ...           Standard               29-12-2022      True
#
#   monthly_spend  primary_device household_size  created_at  duration_clean  \
# 0         25.33          Tablet            3.0     58:10.5             NaN
# 1         36.51        Smart TV            NaN     39:11.8             NaN
# 2         17.12  Gaming Console            1.0     06:21.6             NaN
# 3         37.32        Smart TV            2.0     17:13.7             NaN
# 4          9.91          Tablet            5.0     32:47.5             NaN
#
#            roi is_high_engagement
# 0    -778366.0              False
# 1  391287060.0              False
# 2   31167586.0               True
# 3          NaN               True
# 4    1252192.0              False
#
# [5 rows x 45 columns]

# %%
# Count null values in one column
df_master["country"].isnull().sum()
# Out:
# 0

# %%
df_master['country'].value_counts()
# Out:
# country
# USA       79039
# Canada    33507
# Name: count, dtype: int64

# %%
# checking  if we have enough data for the next batch
print("-" * 30)
print("Data Readiness for Next Questions:")
print(f"Q4 (Devices): {df_master['device_type'].notna().all()} (100% Coverage)")
print(f"Q6 (Churn): {df_master['is_active'].notna().all()} (100% Coverage)")
print(f"Q8 (Gen Z): {df_master['age'].notna().all()} (100% Coverage)")
print("-" * 30)
# Out:
# ------------------------------
# Data Readiness for Next Questions:
# Q4 (Devices): True (100% Coverage)
# Q6 (Churn): True (100% Coverage)
# Q8 (Gen Z): False (100% Coverage)
# ------------------------------

# %%
# Q1: The "Vanity Metric" Exposure (High Views, Low Watch Time)
# Uses df_master because we don't need budget data, just views
q1_stats = df_master.groupby('title').agg({
    'session_id': 'count',
    'progress_percentage': 'mean'
}).rename(columns={'session_id': 'view_count'})

# Filter: Top 20% most viewed, but Bottom 20% retention
high_views = q1_stats['view_count'].quantile(0.80)
low_retention = q1_stats['progress_percentage'].quantile(0.20)

vanity_titles = q1_stats[
    (q1_stats['view_count'] > high_views) & 
    (q1_stats['progress_percentage'] < low_retention)
]

print(f"--- Q1: Identified {len(vanity_titles)} 'Clickbait' Titles ---")
print(vanity_titles.sort_values('view_count', ascending=False).head(3))
# Out:
# --- Q1: Identified 17 'Clickbait' Titles ---
#               view_count  progress_percentage
# title
# Last Phoenix         349            47.363578
# Ice Secret           346            47.591176
# Kingdom War          337            45.911327

# %%
# Q2: The "Sunk Cost" Audit (High Budget, Low Completion)
# Uses df_financials (Only rows with verified budget data)
# Filter: Budget > $20M and Completion < 25%
df_financials = df_master.dropna(subset=['production_budget', 'box_office_revenue']).copy()
sunk_cost_failures = df_financials[
    (df_financials['production_budget'] > 20000000) & 
    (df_financials['progress_percentage'] < 25)
].drop_duplicates('title')

print(f"\n--- Q2: Identified {len(sunk_cost_failures)} Budget Flops (>$20M, <25% Completion) ---")
print(sunk_cost_failures[['title', 'production_budget', 'progress_percentage']].head(3))
# Out:
# --- Q2: Identified 36 Budget Flops (>$20M, <25% Completion) ---
#               title  production_budget  progress_percentage
# 196    Love Journey         23460063.0                 18.7
# 423  Quest Princess         27892159.0                 23.1
# 527   War Adventure         39546152.0                 23.2

# %%
# Q3: Regional ROI Strategy
# Uses df_financials to find which genre makes the most money per country
regional_performance = df_financials.groupby(['location_country', 'genre_primary'])['roi'].median().reset_index()

# Sort to find the top performing genre for each country
top_regional_genres = regional_performance.sort_values(['location_country', 'roi'], ascending=[True, False])
best_per_country = top_regional_genres.groupby('location_country').head(1)

print("\n--- Q3: Best Performing Genre by Country (ROI) ---")
print(best_per_country.head(3))
# Out:
# --- Q3: Best Performing Genre by Country (ROI) ---
#    location_country genre_primary         roi
# 5            Canada         Crime  38477582.0
# 25              USA         Crime  38477582.0

# %%
# Q4: 4K Drop-off on Mobile (Technical Friction)
# We look at 4K content specifically
df_4k = df_master[df_master['quality'] == '4K']
q4_friction = df_4k.groupby('device_type')['progress_percentage'].mean().sort_values()

print("\n--- Q4: 4K Content Completion by Device ---")
print(q4_friction)
if q4_friction.get('Mobile', 100) < q4_friction.get('Desktop', 0) - 10:
    print(">>> INSIGHT: Significant 4K drop-off on Mobile. Recommendation: Disable 4K default on Mobile App.")
# Out:
# --- Q4: 4K Content Completion by Device ---
# device_type
# Smart TV    49.337909
# Desktop     49.740225
# Tablet      49.874920
# Laptop      49.927459
# Mobile      50.310538
# Name: progress_percentage, dtype: float64

# %%
# Q5: Sleeper Hits (Low Budget, High Rating, High Completion)
# We use df_financials here (only rows with budget data)
# Definition: Budget < $5M, Rating > 4, Completion > 70%
sleeper_hits = df_financials[
    (df_financials['production_budget'] < 5000000) &
    (df_financials['user_rating'] >= 4) &
    (df_financials['progress_percentage'] > 70)
]

print(f"\n--- Q5: Identified {len(sleeper_hits)} 'Sleeper Hits' for Promotion ---")
if not sleeper_hits.empty:
    print(sleeper_hits[['title', 'production_budget', 'user_rating']].head(3))
# Out:
# --- Q5: Identified 473 'Sleeper Hits' for Promotion ---
#              title  production_budget  user_rating
# 135     Last Queen          4303395.0          5.0
# 471    Dark Legend          1464928.0          4.0
# 581  First Phoenix           747506.0          5.0

# %%
# Q6: Churn Analysis (Last Watched Content)
# Filter for inactive users and find their latest watch session
inactive_users = df_master[df_master['is_active'] == False]
# Sort by date to get the very last interaction
churn_events = inactive_users.sort_values('watch_date', ascending=False).drop_duplicates('user_id')

print("\n--- Q6: Content Linked to Churn (Top Genres before Cancel) ---")
print(churn_events['genre_primary'].value_counts().head(3))
# Out:
# --- Q6: Content Linked to Churn (Top Genres before Cancel) ---
# genre_primary
# Adventure    103
# Animation     95
# Sci-Fi        91
# Name: count, dtype: int64

# %%
# Q7: Ad-Tier Opportunities (Safe Content, Low Revenue)
# Family Friendly (TV-Y, TV-G, G, PG) but Revenue < Budget (ROI < 0)
safe_ratings = ['TV-Y', 'TV-G', 'G', 'PG', 'TV-Y7']
ad_candidates = df_financials[
    (df_financials['rating'].isin(safe_ratings)) &
    (df_financials['content_warning'] == False) &
    (df_financials['roi'] < 0)
]

print(f"\n--- Q7: Found {len(ad_candidates)} Brand-Safe Titles for Ad-Tier Monetization ---")
print(ad_candidates[['title', 'rating', 'roi']].head(3))
# Out:
# --- Q7: Found 4373 Brand-Safe Titles for Ad-Tier Monetization ---
#               title rating          roi
# 0   Dragon Princess      G    -778366.0
# 42    Fire Princess     PG -191497233.0
# 46      An Princess   TV-G  -48310603.0

# %%
# Q8: Gen-Z Content Strategy (The "False" Fix)
# We filter for users where Age is NOT NaN, then select 18-25
# This handles the "False" coverage issue you saw earlier
df_genz = df_master.dropna(subset=['age'])
df_genz = df_genz[(df_genz['age'] >= 18) & (df_genz['age'] <= 25)]

# Find their favorite genres
genz_favorites = df_genz.groupby('genre_primary')['session_id'].count().sort_values(ascending=False)

print(f"--- Q8: Identified Gen-Z ({len(df_genz)} users) Favorite Genres ---")
print(genz_favorites.head(3))
if not genz_favorites.empty:
    top_genre = genz_favorites.index[0]
    print(f">>> INSIGHT: Gen-Z is heavily indexing on '{top_genre}'. Acquire more of this.")
# Out:
# --- Q8: Identified Gen-Z (14304 users) Favorite Genres ---
# genre_primary
# Adventure    1028
# Animation     905
# Sci-Fi        877
# Name: session_id, dtype: int64
# >>> INSIGHT: Gen-Z is heavily indexing on 'Adventure'. Acquire more of this.

# %%
# Q10: TV Series Decay (The "Cancellation Rule")
# We analyze how engagement drops as the 'Number of Seasons' increases
# Logic: Do shows with 6 seasons have lower completion rates than shows with 1 season?
df_series = df_master[df_master['number_of_seasons'].notna()]

season_decay = df_series.groupby('number_of_seasons')['progress_percentage'].mean().sort_values(ascending=False)

print("\n--- Q10: Viewer Retention by Number of Seasons ---")
print(season_decay.head(5))
# Simple Rule-Based Insight
if len(season_decay) > 1:
    drop_off_check = season_decay.iloc[0] - season_decay.iloc[-1]
    if drop_off_check > 15:
        print(f">>> INSIGHT: Long-running series suffer a {drop_off_check:.1f}% drop in retention. Consider capping at 3-4 seasons.")
# Out:
# --- Q10: Viewer Retention by Number of Seasons ---
# number_of_seasons
# 10.0    51.124624
# 12.0    50.479244
# 7.0     50.420450
# 9.0     50.202060
# 3.0     50.054492
# Name: progress_percentage, dtype: float64

# %%
# Q11: Market Leadership & Ad Strategy (The "Growth" Question)
# Part A: Which country has the most users? (Using the User Database)
# Note: We use 'country' from the users table, not 'location_country' from history, to get the subscriber base.
top_country = df_users['country'].value_counts().idxmax()
num_users = df_users['country'].value_counts().max()

print(f"\n--- Q11: Market Leader Analysis ({top_country}) ---")
print(f"Top Market: {top_country} with {num_users} subscribers.")

# Part B: What are they watching in that country? (Using Watch History)
country_activity = df_master[df_master['location_country'] == top_country]
top_content_local = country_activity.groupby('title')['watch_duration_minutes'].sum().sort_values(ascending=False)

print(f"Dominant Content in {top_country}:")
print(top_content_local.head(3))

if not top_content_local.empty:
    winner = top_content_local.index[0]
    print(f">>> STRATEGY: Prioritize advertisements for '{winner}' in {top_country}. The audience is already hooked.")
# Out:
# --- Q11: Market Leader Analysis (USA) ---
# Top Market: USA with 7204 subscribers.
# Dominant Content in USA:
# title
# A Adventure    29540.5
# A Quest        27727.0
# Love Battle    24731.3
# Name: watch_duration_minutes, dtype: float64
# >>> STRATEGY: Prioritize advertisements for 'A Adventure' in USA. The audience is already hooked.

# %%
# !pip install ydata-profiling --user
# Out:
# Requirement already satisfied: ydata-profiling in c:\users\sohan\appdata\roaming\python\python310\site-packages (4.18.0)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (1.14.0)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from ydata-profiling) (1.9.5)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: visions[type_image_path]<0.8.2,>=0.7.5 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from ydata-profiling) (0.8.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (3.6.2)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from ydata-profiling) (2.12.5)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: pillow in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (10.4.0)
# Requirement already satisfied: PyWavelets in c:\users\sohan\appdata\roaming\python\python310\site-packages (from imagehash==4.3.2->ydata-profiling) (1.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (2.1.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.53.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.2.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.1.2)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from pydantic<3,>=2->ydata-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: puremagic in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\sohan\appdata\roaming\python\python310\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\sohan\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.16.0)
# WARNING: visions 0.8.1 does not provide the extra 'type_image_path'
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df_financials, title="Content Financial Health Audit", minimal=True)

profile.to_file("financial_audit_report.html")
print("SUCCESS: 'financial_audit_report.html' generated (Word Clouds skipped).")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|                                                                                           | 0/45 [00:00<?, ?it/s]
#   2%|█▊                                                                                 | 1/45 [00:00<00:34,  1.27it/s]
#  29%|███████████████████████▋                                                          | 13/45 [00:01<00:02, 12.69it/s]
#  62%|███████████████████████████████████████████████████                               | 28/45 [00:01<00:00, 23.36it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 45/45 [00:01<00:00, 26.91it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 3
#       1 profile = ProfileReport(df_financials, title="Content Financial Health Audit", minimal=True)
# ----> 3 profile.to_file("financial_audit_report.html")
#       4 print("SUCCESS: 'financial_audit_report.html' generated (Word Clouds skipped).")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ydata_profiling\profile_report.py:381, in ProfileReport.to_file(self, output_file, silent)
#     378         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     379     create_html_assets(self.config, output_file)
# --> 381 data = self.to_html()
#     383 if output_file.suffix != ".html":
#     384     suffix = output_file.suffix
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ydata_profiling\profile_report.py:498, in ProfileReport.to_html(self)
#     490 def to_html(self) -> str:
#     491     """Generate and return complete template as lengthy string
#     492         for using with frameworks.
#     493
#    (...)
#     496
#     497     """
# --> 498     return self.html
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ydata_profiling\profile_report.py:294, in ProfileReport.html(self)
#     291 @property
#     292 def html(self) -> str:
#     293     if self._html is None:
# --> 294         self._html = self._render_html()
#     295     return self._html
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ydata_profiling\profile_report.py:411, in ProfileReport._render_html(self)
#     408 def _render_html(self) -> str:
#     409     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 411     report = self.report
#     413     with tqdm(
#     414         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     415     ) as pbar:
#     416         html = HTMLReport(copy.deepcopy(report)).render(
#     417             nav=self.config.html.navbar_show,
#     418             offline=self.config.html.use_local_assets,
#    (...)
#     426             version=self.description_set.package["ydata_profiling_version"],
#     427         )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ydata_profiling\profile_report.py:288, in ProfileReport.report(self)
#     285 @property
#     286 def report(self) -> Root:
#     287     if self._report is None:
# --> 288         self._report = get_report_structure(self.config, self.description_set)
#     289     return self._report
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ydata_profiling\report\structure\report.py:388, in get_report_structure(config, summary)
#     368 section_items: List[Renderable] = [
#     369     Container(
#     370         get_dataset_items(config, summary, alerts),
#    (...)
#     375     ),
#     376 ]
#     378 if len(summary.variables) > 0:
#     379     section_items.append(
#     380         Dropdown(
#     381             name="Variables",
#     382             anchor_id="variables-dropdown",
#     383             id="variables-dropdown",
#     384             is_row=False,
#     385             classes=["form-select"],
#     386             items=list(summary.variables),
#     387             item=Container(
# --> 388                 render_variables_section(config, summary),
#     389                 sequence_type="accordion",
#     390                 name="Variables",
#     391                 anchor_id="variables",
#     392             ),
#     393         )
#     394     )
#     396 scatter_items = get_interactions(config, summary.scatter)
#     397 if len(scatter_items) > 0:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ydata_profiling\report\structure\report.py:162, in render_variables_section(config, dataframe_summary)
#     160     variable_type = summary["type"]
#     161 render_map_type = render_map.get(variable_type, render_map["Unsupported"])
# --> 162 template_variables.update(render_map_type(config, template_variables))
#     164 # Ignore these
#     165 if reject_variables:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ydata_profiling\report\structure\variables\render_text.py:81, in render_text(config, summary)
#      77 top_items.append(table)
#      79 if words and "word_counts" in summary:
#      80     mini_wordcloud = Image(
# ---> 81         plot_word_cloud(config, summary["word_counts"]),
#      82         image_format=config.plot.image_format,
#      83         alt="Mini wordcloud",
#      84     )
#      85     top_items.append(mini_wordcloud)
#      86 template_variables["top"] = Container(top_items, sequence_type="grid")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ydata_profiling\visualisation\plot.py:133, in plot_word_cloud(config, word_counts)
#     131 @manage_matplotlib_context()
#     132 def plot_word_cloud(config: Settings, word_counts: pd.Series) -> str:
# --> 133     _plot_word_cloud(config=config, series=word_counts)
#     134     return plot_360_n0sc0pe(config)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ydata_profiling\visualisation\plot.py:49, in _plot_word_cloud(config, series, figsize)
#      39     wordcloud = WordCloud(
#      40         font_path=config.plot.font_path,
#      41         background_color="white",
#    (...)
#      45         scale=2,
#      46     ).generate_from_frequencies(word_dict)
#      48     ax = plot.add_subplot(1, len(series), i + 1)
# ---> 49     ax.imshow(wordcloud)
#      50     ax.axis("off")
#      52 return plot
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:5604, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5596 self.set_aspect(aspect)
#    5597 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5598                       interpolation=interpolation, origin=origin,
#    5599                       extent=extent, filternorm=filternorm,
#    5600                       filterrad=filterrad, resample=resample,
#    5601                       interpolation_stage=interpolation_stage,
#    5602                       **kwargs)
# -> 5604 im.set_data(X)
#    5605 im.set_alpha(alpha)
#    5606 if im.get_clip_path() is None:
#    5607     # image does not already have clipping set, clip to axes patch
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\image.py:697, in _ImageBase.set_data(self, A)
#     695 if isinstance(A, PIL.Image.Image):
#     696     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 697 self._A = cbook.safe_masked_invalid(A, copy=True)
#     699 if (self._A.dtype != np.uint8 and
#     700         not np.can_cast(self._A.dtype, float, "same_kind")):
#     701     raise TypeError("Image data of dtype {} cannot be converted to "
#     702                     "float".format(self._A.dtype))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\cbook\__init__.py:743, in safe_masked_invalid(x, copy)
#     742 def safe_masked_invalid(x, copy=False):
# --> 743     x = np.array(x, subok=True, copy=copy)
#     744     if not x.dtype.isnative:
#     745         # If we have already made a copy, do the byteswap in place, else make a
#     746         # copy with the byte order swapped.
#     747         x = x.byteswap(inplace=copy).newbyteorder('N')  # Swap to native order.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\wordcloud\wordcloud.py:765, in WordCloud.__array__(self, copy)
#     750 def __array__(self, copy=None):
#     751     """Convert to numpy array.
#     752
#     753     Parameters
#    (...)
#     763         Word cloud image as numpy matrix.
#     764     """
# --> 765     return self.to_array(copy=copy)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\wordcloud\wordcloud.py:748, in WordCloud.to_array(self, copy)
#     733 def to_array(self, copy=None):
#     734     """Convert to numpy array.
#     735
#     736     Parameters
#    (...)
#     746         Word cloud image as numpy matrix.
#     747     """
# --> 748     return np.asarray(self.to_image(), copy=copy)
#
# TypeError: asarray() got an unexpected keyword argument 'copy'

# %%
# Save the "Brain" to disk so Streamlit can use it
print("Exporting processed data for Streamlit...")

# 1. Save the Master View (For Q1, Q4, Q6, Q8, Q10, Q11)
df_master.to_csv('processed_master.csv', index=False)

# 2. Save the Financial View (For Q2, Q3, Q5, Q7)
df_financials.to_csv('processed_financials.csv', index=False)

print("SUCCESS: 'processed_master.csv' and 'processed_financials.csv' saved.")
print("You are now ready to switch to VS Code.")
# Out:
# Exporting processed data for Streamlit...
# SUCCESS: 'processed_master.csv' and 'processed_financials.csv' saved.
# You are now ready to switch to VS Code.
